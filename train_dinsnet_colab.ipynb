# %% [markdown]
# # DINSNet Training on Google Colab
#
# This notebook simplifies the process of training the DINSNet model on Google Colab using a GPU. It handles environment setup, dependency installation, and provides commands to train on specific datasets.
#
# ### Step 1: Check GPU
# Ensure you have a GPU allocated for this session (Edit > Notebook settings > Hardware accelerator > GPU).

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Mount Google Drive
# Upload your project folder (DINSNet) and datasets to your Google Drive, then run this cell to mount it.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 3: Setup Project Directory
# Update `PROJECT_PATH` to point to your DINSNet folder in Google Drive.

# %%
import os
PROJECT_PATH = '/content/drive/MyDrive/DINSNet' # Update this if needed
# %cd {PROJECT_PATH}

# %% [markdown]
# ### Step 4: Install Dependencies

# %%
# !pip install -r requirements.txt
# Ensure thop is installed for FLOPs calculation if not in requirements
# !pip install thop

# %% [markdown]
# ### Step 5: Training
# Run the desired training command. These will use the specific config files for each dataset.

# %% [markdown]
# #### Train on CVC-ColonDB

# %%
# !python main.py --config config_debug_CVC-ColonDB.yaml --mode train

# %% [markdown]
# #### Train on Kvasir

# %%
# !python main.py --config config_debug_Kvasir.yaml --mode train
